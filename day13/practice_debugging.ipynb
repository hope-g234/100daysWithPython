# %%
def my_func():
    for i in range(1, 20):
        if i == 20:
            print("You got it")
#bug in range,

# %%
# Reproduce the bug
#List always starts from zero
import random

Animal_image = [ "🐶" ,"🐱" ,"🐹" ,"🐰", "🦊", "🐻"]
animal_num = random.randint(1,6) # 0-5 index out of range error
print(Animal_image[animal_num])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[52], line 7
#       5 Animal_image = [ "🐶" ,"🐱" ,"🐹" ,"🐰", "🦊", "🐻"]
#       6 animal_num = random.randint(1,6)
# ----> 7 print(Animal_image[animal_num])
#
# IndexError: list index out of range

# %%
# use try and catch
try:
    age = int(input("Enter your age: "))
except ValueError:
    print("Please enter an integer")
    age = int(input("Enter your age: "))
# Out:
# Please enter an integer

# %%
# == evaluate true or false
#Debugger-Thony and python tutor
