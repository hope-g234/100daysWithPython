# %%
def format_name(f_name , l_name):
    formated_f = f_name.title()
    formatted_l= l_name.title()

    print(f"{formated_f} {formatted_l}")

format_name("gokula", "GOPALA")
# Out:
# Gokula Gopala

# %%
def function1(text):
     last = input("Enter your second name !")
     if text =="" or last == "":
         return "Please enter your name"
     return  text +""+ last

def function2(text):
    return text.title()

output = function2(function1(input("Enter your first name ! ")))
print(output)
# Out:
# Please Enter Your Name

# %%
# Docstrings
"""string in multiple line as many line as want like documentation like explainer"""
