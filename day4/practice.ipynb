# %%
import random

random_integer=random.randint(1,10)
print(random_integer)
# Out:
# 5

# %%
import practice1
#create module
print(practice1.Number)
# Out:
# 67

# %%
# create floating random number 0 to 1
random_float_0to1 = random.random() * 10 # include 0 but never 1
print(random_float_0to1)

random_float = random.uniform(1,10)
print(random_float)
# Out:
# 7.332378720532371
# 3.453667936802968

# %%
random_H_or_T = random.randint(0,1)
if random_H_or_T==0:
    print("Heads")
else:
    print("tails")
# Out:
# tails

# %%
#Lists- data structure , always starts with [] and can have mixed data
# can store related data but order matters
state_names=["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware", "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana", "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", "Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico", "New York", "North Carolina", "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", "West Virginia", "Wisconsin", "Wyoming"]
state_names[-1]
#state_names[-2] = "Karnataka" can alter
state_names.append("Mandya") # will add in the end
lenght = len(state_names)
print(state_names[lenght-1])
print(state_names)
# Out:
# Mandya
# ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming', 'Mandya']

# %%
friends= ["Alice","Bob","Charlie","David","mina"]
print(random.choice(friends))

random_index= random.randint(0,4)
print(friends[random_index])
# Out:
# David
# Bob

# %%
#nested list
